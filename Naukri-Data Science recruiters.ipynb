# %%
# !pip install selenium

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings 
warnings.filterwarnings('ignore')

# %%
driver=webdriver.Chrome(r'C:\Users\AYUSHI\Downloads\chromedriver_win32\chromedriver.exe')

# %%
url='https://www.naukri.com/browse-jobs'
driver.get(url)

# %%
Url=[]
for i in driver.find_elements_by_xpath("//ul[@class='midSec menu']/li[2]/a"):
    Url.append(i.get_attribute("href"))
Url
# Out:
# ['https://www.naukri.com/recruiters']

# %%
driver.get(Url[0])

# %%
search_job=driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/div/div[1]/div[1]/div[2]/input')
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="800ba729f2a037ee5d04abf0d560463a", element="533806a2-7f9e-4078-bcd0-379a0a8a5149")>

# %%
search_job.send_keys('Data Science')

# %%
search_btn=driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/button')
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="800ba729f2a037ee5d04abf0d560463a", element="ae2caa46-100c-4e52-82bc-e5dade5fe6f0")>

# %%
search_btn.click()

# %%
name=driver.find_elements_by_xpath('//span[@class="fl ellipsis"]')
len(name)
# Out:
# 50

# %%
Name=[]
for j in name:
    Name.append(j.text)
Name
# Out:
# ['Aakash Harit',
#  'shravan Kumar Gaddam',
#  'MARSIAN Technologies LLP',
#  'Anik Agrawal',
#  'subhas patel',
#  'Abhishek - Only Analytics Hiring - India and',
#  'Institute for Financial Management and Resear',
#  'Balu Ramesh',
#  'Asif Lucknowi',
#  'InstaFinancials',
#  'Priyanka Akiri',
#  'Kalpana Dumpala',
#  'Mubarak',
#  'Kushal Rastogi',
#  'Mahesh Babu Channa',
#  'Sakshi Chhikara',
#  'Kapil Devang',
#  'Ruchi Dhote',
#  'Sandhya Khandagale',
#  'Manisha Yadav',
#  'Riya Rajesh',
#  'Rashmi Bhattacharjee',
#  'Faizan Kareem',
#  'Rithika dadwal',
#  'Shaun Rao',
#  'Azahar Shaikh',
#  'Manas',
#  'kumar',
#  'Sunil Vedula',
#  'Rajat Kumar',
#  'Dhruv Dev Dubey',
#  'Avodha',
#  'Jayanth N',
#  'Priya Khare',
#  'Amit Sharma',
#  'Kanan',
#  'Shashikant Chaudhary',
#  'Brad',
#  'Rutuja Pawar',
#  'Madhusudhan Sridhar',
#  'Ankit Sinha',
#  'Gaurav Chouhan',
#  'Rashi Kacker',
#  'Ashwini',
#  'Balaji Kolli',
#  'Rajani Nagaraj',
#  'ROHIT Kumar',
# ...

# %%
des=driver.find_elements_by_xpath('//span[@class="ellipsis clr"]')
len(des)
# Out:
# 50

# %%
Designation=[]
for k in des:
    Designation.append(k.text)
Designation
# Out:
# ['HR Manager',
#  'Company Recruiter',
#  'Company HR',
#  'Company Recruiter',
#  'Founder CEO',
#  'Recruitment Lead Consultant',
#  'Programme Manager',
#  'HR Administrator',
#  'Director',
#  'Human Resource',
#  'HR Manager',
#  'Executive Hiring',
#  'Company HR',
#  'Company HR',
#  'HR Team Lead',
#  'Assistant Manager HR',
#  'HR Manager',
#  'Senior Executive Talent Acquisition',
#  'HR Recruiter',
#  'HR Executive',
#  'Manager Talent Acquisition',
#  'HR Head',
#  'HR MANAGER',
#  'HR Recruiter',
#  'Manager Human Resources',
#  'Company Recruiter',
#  'Lead Talent acquisition',
#  'Proprietor',
#  'CEO',
#  'Founder CEO',
#  'Company Recruitment Head',
#  'Business Development Associate',
#  'Project Manager',
#  'Senior Manager',
#  'Consultant',
#  'senior technology instructor',
#  'HR Recruiter/HR Excutive',
#  'Manager, Technical Recruiting',
#  'Technical Recruiter',
#  'Erp Implementer',
#  'Head Analytics',
#  'Chief Technical Officer',
#  'Sr Product Manager',
# ...

# %%
comp=driver.find_elements_by_xpath('//p[@class="highlightable"]/a[2]')
len(comp)
# Out:
# 50

# %%
Company=[]
for k in comp:
    Company.append(k.text)
Company
# Out:
# ['Data Science Network',
#  'Shore Infotech India Pvt. Ltd',
#  'MARSIAN Technologies LLP',
#  'Enerlytics Software Solutions Pvt Ltd',
#  'LibraryXProject',
#  'Apidel Technologies Division of Transpower',
#  'IFMR',
#  'Techvantage Systems Pvt Ltd',
#  'Weupskill- Live Wire India',
#  'CBL Data Science Private Limited',
#  'Infinitive Software Solutions',
#  'Innominds Software',
#  'MoneyTap',
#  'QuantMagnum Technologies Pvt. Ltd.',
#  'SocialPrachar.com',
#  'BIZ INFOTECNO PRIVATE LIMITED',
#  'BISP Solutions',
#  'Bristlecone India Ltd',
#  'Compumatrice Multimedia Pvt Ltd',
#  'Easi Tax',
#  'Novelworx Digital Solutions',
#  'AXESTRACK SOFTWARE SOLUTIONS PRIVATE...',
#  'FirstTech Consaltants Pvt.Ltd',
#  'Affine Analytics',
#  'Exela Technologies',
#  'NEAL ANALYTICS SERVICES PVT LTD',
#  'Autumn Leaf Consulting Services Private...',
#  'trainin',
#  'Nanoprecise Sci Corp',
#  'R.S Consultancy &amp; Services',
#  'Confidential',
#  'Nikitha Palaparthi',
# ...

# %%
skills=driver.find_elements_by_xpath('//div[@class="hireSec highlightable"]')
len(skills)
# Out:
# 50

# %%
Skills=[]
for k in skills:
    Skills.append(k.text)
Skills
# Out:
# ['Classic ASP Developer, Internet Marketing Professional, Data Science SME, Content Writers, SEO Professional, Revenue Professional',
#  '.Net, Java, Data Science, Linux Administration, Sql Server Development, Winforms, Wcf Services, Wpf, Telecom Engineering, Technical Management, Software',
#  'Data Science, Artificial Intelligence, Machine Learning, Business Analytics, Deep Learning, statistics, Data Analytics, Data Analysis, support vector machine',
#  'Mean Stack, javascript, angularjs, mongodb, Web Services, rest, express, Node.js, Big Data, iot, Data Science, Cloud Computing, saas, Aws',
#  'Hadoop, Spark, Digital Strategy, Data Architecture, Command Center, Cdp, Dmp, Kafka, Data Science, Data Analysis, Big Data Analytics, Real Time Analysis, SQL',
#  'Analytics, Business Intelligence, Business Analytics, Predictive Modeling, Predictive Analytics, Data Science, Data Analysis, Data Analytics, Big Data, Big',
#  'Data Science',
# ...

# %%
loc=driver.find_elements_by_xpath('//p[@class="highlightable"]/span[2]/small')
len(loc)
# Out:
# 48

# %%
Location=[]
for k in loc:
    Location.append(k.text)
Location
# Out:
# ['Delhi',
#  'Hyderabad / Secunderabad',
#  'Pune',
#  'Ahmedabad',
#  'UK - (london)',
#  'Vadodara / Baroda',
#  'Chennai',
#  'Trivandrum',
#  'Indore',
#  'Bengaluru / Bangalore',
#  'Hyderabad',
#  'Hyderabad / Secunderabad',
#  'Bengaluru / Bangalore',
#  'Mumbai',
#  'Hyderabad / Secunderabad',
#  'Chandigarh',
#  'Bhopal',
#  'Pune',
#  'Pune',
#  'Navi Mumbai',
#  'Cochin',
#  'Delhi',
#  'Hyderabad / Secunderabad',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Bengaluru / Bangalore',
#  'Bengaluru / Bangalore',
#  'Delhi',
#  'Bengaluru / Bangalore',
#  'Hyderabad / Secunderabad',
#  'Mysoru / Mysore',
#  'Bengaluru / Bangalore',
#  'New Delhi',
#  'Chennai',
#  'Aligarh',
#  'Salt Lake City',
#  'Pune',
#  'Bengaluru / Bangalore',
#  'Mumbai',
#  'Indore',
#  'Bengaluru / Bangalore',
#  'MYSORE',
#  'Hyderabad / Secunderabad',
#  'Bengaluru / Bangalore',
#  'Mumbai',
#  'Bengaluru / Bangalore',
#  'Hyderabad / Secunderabad']

# %%
Location1=Location
Location1.insert(46,"NA")
Location1.insert(28,"NA")
Location1
# Out:
# ['Delhi',
#  'Hyderabad / Secunderabad',
#  'Pune',
#  'Ahmedabad',
#  'UK - (london)',
#  'Vadodara / Baroda',
#  'Chennai',
#  'Trivandrum',
#  'Indore',
#  'Bengaluru / Bangalore',
#  'Hyderabad',
#  'Hyderabad / Secunderabad',
#  'Bengaluru / Bangalore',
#  'Mumbai',
#  'Hyderabad / Secunderabad',
#  'Chandigarh',
#  'Bhopal',
#  'Pune',
#  'Pune',
#  'Navi Mumbai',
#  'Cochin',
#  'Delhi',
#  'Hyderabad / Secunderabad',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Bengaluru / Bangalore',
#  'Bengaluru / Bangalore',
#  'NA',
#  'Delhi',
#  'Bengaluru / Bangalore',
#  'Hyderabad / Secunderabad',
#  'Mysoru / Mysore',
#  'Bengaluru / Bangalore',
#  'New Delhi',
#  'Chennai',
#  'Aligarh',
#  'Salt Lake City',
#  'Pune',
#  'Bengaluru / Bangalore',
#  'Mumbai',
#  'Indore',
#  'Bengaluru / Bangalore',
#  'MYSORE',
#  'Hyderabad / Secunderabad',
#  'Bengaluru / Bangalore',
#  'Mumbai',
#  'NA',
#  'Bengaluru / Bangalore',
#  'Hyderabad / Secunderabad']

# %%
recruiters=pd.DataFrame()
recruiters['Name']= Name
recruiters['Designation']= Designation
recruiters['Company ']= Company
recruiters['Skills they hire for']= Skills
recruiters['Location']= Location1
recruiters
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                 Priyanka Akiri
# 11                                Kalpana Dumpala
# 12                                        Mubarak
# 13                                 Kushal Rastogi
# 14                             Mahesh Babu Channa
# 15                                Sakshi Chhikara
# 16                                   Kapil Devang
# 17                                    Ruchi Dhote
# ...
